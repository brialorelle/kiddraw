# %%
## remember to run conn_cocolab from the terminal before running cells in this notebook!
import os
import urllib, cStringIO

import pymongo as pm

import matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import seaborn as sns
sns.set_context('poster')
sns.set_style('white')

import numpy as np
from __future__ import division
import scipy.stats as stats
import pandas as pd
import json
import re

from PIL import Image
import base64

# %% [markdown]
# ### file hierarchy and database connection vars

# %%
# directory & file hierarchy
iterationName = 'Bingphotodraw_pilot'
exp_path = 'photodraw'
analysis_dir = os.getcwd()
exp_dir = os.path.abspath(os.path.join(os.getcwd(),'../..','experiments'))
##
sketch_dir = os.path.join(analysis_dir,'sketches')
if not os.path.exists(sketch_dir):
    os.makedirs(sketch_dir)
## dir where we can keep all sketches not binned by category

# %%
# set vars 
auth = pd.read_csv('auth.txt', header = None) # this auth.txt file contains the password for the sketchloop user
pswd = auth.values[0][0]
user = 'sketchloop'
host = 'rxdhawkins.me' ## cocolab ip address

# have to fix this to be able to analyze from local
import pymongo as pm
conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1')
db = conn['kiddraw']
coll = db['Bing_photodraw_e1']

# %% [markdown]
# ### Preprocessing data and rendering images

# %% [markdown]
# Notes:
# There are two types of records in the database: 'stroke' and 'finalImage'. This is stored under the key: 'dataType'.
# The 'stroke'-type of record contains the svg string information. Every stroke event is stored as a separate record.
# The session identifier is called "sessionId".

# %%
# experiment_name = 'Bingphotodraw_pilot'
experiment_name = 'Bing_photodraw_e1'

all_sessions = coll.distinct('sessionId') ## this returns ALL sessions in this collection. we will then filter on time_threshold
valid_sessions = coll.find().distinct('sessionId')
print 'We currently have {} valid sessions from {}.'.format(len(valid_sessions), experiment_name)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-4-c633e8f09b82> in <module>()
#       3 experiment_name = 'Bing_photodraw_e1'
#       4
# ----> 5 all_sessions = coll.distinct('sessionId') ## this returns ALL sessions in this collection. we will then filter on time_threshold
#       6 valid_sessions = coll.find().distinct('sessionId')
#       7 print 'We currently have {} valid sessions from {}.'.format(len(valid_sessions), experiment_name)
#
# /Users/brialong/.local/lib/python2.7/site-packages/pymongo/collection.pyc in distinct(self, key, filter, **kwargs)
#    2057         collation = validate_collation_or_none(kwargs.pop('collation', None))
#    2058         cmd.update(kwargs)
# -> 2059         with self._socket_for_reads() as (sock_info, slave_ok):
#    2060             return self._command(sock_info, cmd, slave_ok,
#    2061                                  read_concern=self.read_concern,
#
# /Users/brialong/anaconda2/lib/python2.7/contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# /Users/brialong/.local/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _socket_for_reads(self, read_preference)
#     902         topology = self._get_topology()
#     903         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# --> 904         with self._get_socket(read_preference) as sock_info:
#     905             slave_ok = (single and not sock_info.is_mongos) or (
#     906                 preference != ReadPreference.PRIMARY)
#
# /Users/brialong/anaconda2/lib/python2.7/contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# /Users/brialong/.local/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _get_socket(self, selector)
#     866     @contextlib.contextmanager
#     867     def _get_socket(self, selector):
# --> 868         server = self._get_topology().select_server(selector)
#     869         try:
#     870             with server.get_socket(self.__all_credentials) as sock_info:
#
# /Users/brialong/.local/lib/python2.7/site-packages/pymongo/topology.pyc in select_server(self, selector, server_selection_timeout, address)
#     212         return random.choice(self.select_servers(selector,
#     213                                                  server_selection_timeout,
# --> 214                                                  address))
#     215
#     216     def select_server_by_address(self, address,
#
# /Users/brialong/.local/lib/python2.7/site-packages/pymongo/topology.pyc in select_servers(self, selector, server_selection_timeout, address)
#     187                 if server_timeout == 0 or now > end_time:
#     188                     raise ServerSelectionTimeoutError(
# --> 189                         self._error_message(selector))
#     190
#     191                 self._ensure_opened()
#
# ServerSelectionTimeoutError: 127.0.0.1:27017: [Errno 61] Connection refused

# %%
# Out:
# 105

# %%
really_run_this = 1
if really_run_this:
    ## img writing parameters
    imsize = 224
    
    ## desired output: a dataframe that has trials on the rows, and the following columns:
    ## category, age, number of strokes, mean_pixel_intensity, bounding_box_coordinates_LTRB, list of strokes, 
    ## PNG string, submission_time, submission_date
    ## to be saved out as a nice tidy CSV
    session_id = []
    trial_num = []
    category = []
    num_strokes = []
    mean_pixel_intensity = []
    bounding_box_coords = []
    svg = []
    kidName = []
    svg_times = []
    png = []
    submit_time = []
    submit_date = []
    draw_duration = []
    filename = []
    countErr = 0
    condition=[]
    subID=[]
    
    for s in valid_sessions:
        this_collection = coll
        image_recs = this_collection.find({'$and': [{'sessionId':s}, {'dataType':'finalImage'}]}).sort('time')    
        for imrec in image_recs:   
            if imrec['subID']!="Sub01" and imrec['subID']!="Test01" and imrec['subID']!="Test02" and imrec['subID']!="Test04":
                stroke_recs = this_collection.find({'$and': [ 
                                                  {'sessionId':s}, 
                                                  {'dataType':'stroke'},
                                                  {'trialNum': imrec['trialNum']}]}).sort('time')   

                if stroke_recs.count() > 0: ## only include trials if the drawings are not blank            
                    session_id.append(imrec['sessionId'])        
                    trial_num.append(imrec['trialNum']) 
                    category.append(imrec['category'])
 
                    try:    
                        png.append(imrec['imgData'])
                        submit_time.append(imrec['time'])
                        submit_date.append(imrec['date'])
                        condition.append(imrec['condition'])
                        subID.append(imrec['subID'])
                        filename.append(os.path.join(sketch_dir,'{}_sketch_{}_{}_{}.png'.format(imrec['category'], imrec['subID'],imrec['sessionId'], imrec['condition'])))
                        num_strokes.append(stroke_recs.count())
                        _svg = [] # this keeps track of the strokes from THIS final image
                        _svg_times = []
                        for strec in stroke_recs:
                            _svg.append(strec['svg'])
                            _svg_times.append(strec['time'])
                        draw_duration.append((_svg_times[-1] - _svg_times[0])/1000) ## in seconds
                        svg.append(_svg)
                        svg_times.append(_svg_times)

                        ## and write out image data here too
                        imgData = imrec['imgData'];
                        filestr = base64.b64decode(imgData)
                        child_dir = os.path.join(sketch_dir,imrec['kidName'])
                        if not os.path.exists(child_dir):
                            os.makedirs(child_dir)
                        fname = os.path.join(child_dir,'{}_sketch_{}_{}_{}.png'.format(imrec['category'], imrec['subID'],imrec['sessionId'],imrec['condition']))
                        with open(fname, "wb") as fh:
                            fh.write(imgData.decode('base64'))  
                    except:
                        print('something went wrong with an image')
                        countErr = countErr + 1
                        print imrec['category']
                        child_dir = os.path.join(sketch_dir,'noname')
                        if not os.path.exists(child_dir):
                            os.makedirs(child_dir)
                        fname = os.path.join(child_dir,'{}_sketch_{}_{}.png'.format(imrec['category'], 'noname',imrec['sessionId']))
                        with open(fname, "wb") as fh:
                            fh.write(imgData.decode('base64'))

# %%
imrec
# Out:
# {u'_id': ObjectId('5b44e45807aab50b0de228ce'),
#  u'category': u'this shape',
#  u'condition': u'S',
#  u'counter_balancing': u'1',
#  u'dataType': u'finalImage',
#  u'date': u'2018-07-10T16:52:40.747Z',
#  u'imgData': u'...',
#  u'kidName': u'TEST TEST',
#  u'location': u'Bing',
#  u'sessionId': u'Bingphotodraw_pilot1531241475109',
#  u'time': 1531241560747.0,
#  u'trialNum': 1}

# %%
if really_run_this:
    X = pd.DataFrame([session_id,trial_num,condition,category,subID,submit_time,submit_date,num_strokes,svg,svg_times,png,draw_duration,filename])
    X = X.transpose()
    X.columns = ['session_id','trial_num','condition','category','subID','submit_time','submit_date','num_strokes','svg','svg_times','png','draw_duration', 'filename']

# %%
X
# Out:
#                          session_id trial_num condition     category  subID  \
# 0    Bing_photodraw_e11531411158419         0         S  this square  Sub02
# 1    Bing_photodraw_e11531411158419         1         S   this shape  Sub02
# 2    Bing_photodraw_e11531411158419         2         S  this circle  Sub02
# 3    Bing_photodraw_e11531411158419         3         W          cup  Sub02
# 4    Bing_photodraw_e11531411158419         4         W        train  Sub02
# 5    Bing_photodraw_e11531411158419         5         W          cat  Sub02
# 6    Bing_photodraw_e11531411158419         6         W       rabbit  Sub02
# 7    Bing_photodraw_e11531411158419         7         W         shoe  Sub02
# 8    Bing_photodraw_e11531411158419         8         S          cup  Sub02
# 9    Bing_photodraw_e11531411158419         9         S       rabbit  Sub02
# 10   Bing_photodraw_e11531411158419        10         S          cat  Sub02
# 11   Bing_photodraw_e11531411158419        12         S        train  Sub02
# 12   Bing_photodraw_e11531411158419        13         P          cup  Sub02
# 13   Bing_photodraw_e11531411158419        14         P       rabbit  Sub02
# 14   Bing_photodraw_e11531411158419        15         P         shoe  Sub02
# 15   Bing_photodraw_e11531411158419        16         P        train  Sub02
# 16   Bing_photodraw_e11531411158419        17         P          cat  Sub02
# 17   Bing_photodraw_e11531415239947         0         S  this square  Sub03
# 18   Bing_photodraw_e11531415239947         1         S   this shape  Sub03
# 19   Bing_photodraw_e11531415239947         2         S  this circle  Sub03
# 20   Bing_photodraw_e11531415239947         3         S          cup  Sub03
# 21   Bing_photodraw_e11531415239947         4         S         shoe  Sub03
# 22   Bing_photodraw_e11531415239947         5         S       rabbit  Sub03
# 23   Bing_photodraw_e11531415239947         6         S          cat  Sub03
# 24   Bing_photodraw_e11531415239947         7         S        train  Sub03
# 25   Bing_photodraw_e11531415239947         8         P          cup  Sub03
# 26   Bing_photodraw_e11531415239947         9         P       rabbit  Sub03
# 27   Bing_photodraw_e11531415239947        10         P        train  Sub03
# 28   Bing_photodraw_e11531415239947        11         P         shoe  Sub03
# 29   Bing_photodraw_e11531415239947        12         P          cat  Sub03
# ..                              ...       ...       ...          ...    ...
# 71   Bing_photodraw_e11531846221866         0         S  this square  Sub06
# 72   Bing_photodraw_e11531846221866         1         S   this shape  Sub06
# 73   Bing_photodraw_e11531846221866         2         S  this circle  Sub06
# 74   Bing_photodraw_e11531846221866         3         P          cup  Sub06
# 75   Bing_photodraw_e11531846221866         4         P       rabbit  Sub06
# 76   Bing_photodraw_e11531846221866         5         P          cat  Sub06
# 77   Bing_photodraw_e11531846221866         6         P        train  Sub06
# 78   Bing_photodraw_e11531846221866         7         P         shoe  Sub06
# 79   Bing_photodraw_e11531846221866         8         W          cup  Sub06
# 80   Bing_photodraw_e11531846221866         9         W        train  Sub06
# 81   Bing_photodraw_e11531846221866        10         W          cat  Sub06
# 82   Bing_photodraw_e11531846221866        11         W       rabbit  Sub06
# 83   Bing_photodraw_e11531846221866        12         W         shoe  Sub06
# 84   Bing_photodraw_e11531846221866        13         S          cup  Sub06
# 85   Bing_photodraw_e11531846929758         0         S  this square  Sub07
# 86   Bing_photodraw_e11531846929758         1         S   this shape  Sub07
# 87   Bing_photodraw_e11531846929758         2         S  this circle  Sub07
# 88   Bing_photodraw_e11531846929758         3         W          cup  Sub07
# 89   Bing_photodraw_e11531846929758         4         W          cat  Sub07
# 90   Bing_photodraw_e11531846929758         5         W       rabbit  Sub07
# 91   Bing_photodraw_e11531846929758         6         W        train  Sub07
# 92   Bing_photodraw_e11531846929758         7         W         shoe  Sub07
# 93   Bing_photodraw_e11531846929758         8         P          cup  Sub07
# 94   Bing_photodraw_e11531846929758         9         P         shoe  Sub07
# 95   Bing_photodraw_e11531846929758        10         P        train  Sub07
# 96   Bing_photodraw_e11531846929758        11         P          cat  Sub07
# 97   Bing_photodraw_e11531846929758        13         S          cup  Sub07
# 98   Bing_photodraw_e11531846929758        14         S        train  Sub07
# 99   Bing_photodraw_e11531846929758        15         S         shoe  Sub07
# 100  Bing_photodraw_e11531846929758        16         S       rabbit  Sub07
#
#      submit_time               submit_date num_strokes  \
# 0    1.53141e+12  2018-07-12T16:56:35.788Z           7
# 1    1.53141e+12  2018-07-12T16:57:13.564Z           1
# 2    1.53141e+12  2018-07-12T16:57:50.871Z          13
# 3    1.53141e+12  2018-07-12T16:58:34.808Z           5
# 4    1.53141e+12  2018-07-12T16:59:12.111Z           3
# 5    1.53141e+12  2018-07-12T16:59:49.551Z           2
# 6    1.53141e+12  2018-07-12T17:00:27.096Z           4
# 7    1.53141e+12  2018-07-12T17:01:03.986Z          15
# 8    1.53141e+12  2018-07-12T17:01:46.874Z           2
# 9    1.53141e+12  2018-07-12T17:02:23.999Z           3
# 10   1.53141e+12  2018-07-12T17:03:00.779Z           4
# 80   [M86.71875,512.51563l7,4h2h2h2h2l3,1l2,1l3,1l3...
# 81   [M112.71875,456.51563l-8,4l-3,1l-2,3l-2,3l-2,3...
# 82   [M268.71875,545.51563l-9,1h-10h-10h-7h-8h-7h-6...
# 83   [M41.71875,322.51563l5,7l4,3l4,2l4,2l5,2l5,2l6...
# 84   [M230.71875,101.51563l-5,8l-1,7l-3,7l-3,8l-3,9...
# 85   [M467.71875,362.51563l-8,-4l-4,-1l-3,-3l-3,-2l...
# 86   [M411.71875,333.51563l1,-9v-2v-2v-3v-3v-3v-3v-...
# 87   [M374.71875,23.51563l-4,-1h-1h-1l-1,-1l-1,-1l-...
# 88   [M286.71875,599.51563l-5,-10v-2v-2v-2l-1,-3v-2...
# 89   [M141.71875,502.51563l-12,-7h-1l-1,-1l-1,-1l-1...
# 90   [M126.71875,530.51563l-6,-11l-2,-3l-4,-7l-1,-5...
# 91   [M24.71875,400.51563l12,-3l9,-1l11,-1l12,-1h14...
# 92   [M19.71875,422.51563v0l7,4h3h3h3h3h4l5,-1h5h4,...
# 93   [M82.71875,562.51563l-5,4v2, M66.71875,585.515...
# 94   [M37.71875,394.51563l3,-3h2h2h3h3h3h3h3h3h3h3h...
# 95   [M48.71875,395.51563l4,-2h7l6,-1l8,-1l9,-1l9,-...
# 96   [M96.71875,562.51563l-10,-9l-2,-3l-3,-4l-3,-4l...
# 97   [M97.71875,457.51563l-10,-2h-5h-4l-1,1h-2h-1l-...
# 98   [M105.71875,570.51563l-7,-1h-3l-5,-1l-2,-1v-2l...
# 99   [M361.71875,497.51563l5,-7l3,-7l4,-7l5,-8l5,-1...
# 100  [M162.71875,377.51563l-3,-13l-3,-24v-11v-12v-1...
#
#                                              svg_times  \
# 0    [1.53141456708e+12, 1.53141457248e+12, 1.53141...
# 1                                  [1.53141461989e+12]
# 2    [1.53141464648e+12, 1.53141464648e+12, 1.53141...
# 3    [1.5314146903e+12, 1.53141469563e+12, 1.531414...
# 4    [1.53141472834e+12, 1.53141473733e+12, 1.53141...
# 5                 [1.5314147626e+12, 1.5314147626e+12]
# 6    [1.53141480079e+12, 1.53141480079e+12, 1.53141...
# 7    [1.53141483955e+12, 1.53141484255e+12, 1.53141...
# 8                [1.5314148813e+12, 1.53141488294e+12]
# 9    [1.53141491707e+12, 1.53141491707e+12, 1.53141...
# 10   [1.5314149557e+12, 1.5314149557e+12, 1.5314149...
# 11   [1.53141502564e+12, 1.53141502565e+12, 1.53141...
# 12   [1.53141507004e+12, 1.53141507004e+12, 1.53141...
# 13   [1.53141509563e+12, 1.53141509756e+12, 1.53141...
# 14   [1.53141513453e+12, 1.53141513578e+12, 1.53141...
# 15   [1.53141515698e+12, 1.53141515698e+12, 1.53141...
# 16   [1.53141519126e+12, 1.53141519368e+12, 1.53141...
# 17                                 [1.53141782082e+12]
# 18                                 [1.53141784324e+12]
# 19                                 [1.53141785715e+12]
# 20   [1.53141787623e+12, 1.53141787868e+12, 1.53141...
# 21              [1.53141789284e+12, 1.53141789649e+12]
# 22   [1.5314179064e+12, 1.53141790819e+12, 1.531417...
# 23   [1.53141792657e+12, 1.53141792744e+12, 1.53141...
# 24   [1.53141794674e+12, 1.5314179484e+12, 1.531417...
# 25   [1.53141799682e+12, 1.53141799682e+12, 1.53141...
# 26   [1.53141801478e+12, 1.53141801972e+12, 1.53141...
# 27   [1.53141805008e+12, 1.53141805206e+12, 1.53141...
# 28               [1.53141807827e+12, 1.5314180826e+12]
# 29   [1.53141809297e+12, 1.53141809437e+12, 1.53141...
# ..                                                 ...
# 71                                 [1.53184653109e+12]
# 72                                 [1.53184655756e+12]
# 73              [1.53184656922e+12, 1.53184657244e+12]
# 74   [1.53184659447e+12, 1.53184659642e+12, 1.53184...
# 75   [1.53184663555e+12, 1.5318466378e+12, 1.531846...
# 76   [1.53184666641e+12, 1.53184666641e+12, 1.53184...
# 77   [1.53184671008e+12, 1.53184671487e+12, 1.53184...
# 78   [1.53184674281e+12, 1.53184674377e+12, 1.53184...
# 79   [1.53184677835e+12, 1.53184677954e+12, 1.53184...
# 80   [1.53184680481e+12, 1.53184681079e+12, 1.53184...
# 81   [1.53184683805e+12, 1.53184684039e+12, 1.53184...
# 82              [1.53184686156e+12, 1.53184686317e+12]
# 83   [1.53184687282e+12, 1.53184687478e+12, 1.53184...
# 84   [1.53184691132e+12, 1.53184691278e+12, 1.53184...
# 85              [1.53184992992e+12, 1.53184993868e+12]
# 86   [1.53184995532e+12, 1.53184995607e+12, 1.53184...
# 87   [1.5318499952e+12, 1.5318499952e+12, 1.5318499...
# 88   [1.53185002141e+12, 1.53185002306e+12, 1.53185...
# 89   [1.53185003946e+12, 1.5318500437e+12, 1.531850...
# 90   [1.53185007127e+12, 1.5318500737e+12, 1.531850...
# 91              [1.53185010004e+12, 1.53185010656e+12]
# 92   [1.53185011509e+12, 1.53185011509e+12, 1.53185...
# 93   [1.53185014023e+12, 1.53185014478e+12, 1.53185...
# 94   [1.53185016416e+12, 1.53185016988e+12, 1.53185...
# 95   [1.53185019157e+12, 1.53185019756e+12, 1.53185...
# 96   [1.53185021781e+12, 1.5318502203e+12, 1.531850...
# 97   [1.53185024878e+12, 1.53185025589e+12, 1.53185...
# 98   [1.5318502701e+12, 1.53185027328e+12, 1.531850...
# 99                                 [1.53185029284e+12]
# 100                                [1.53185030326e+12]
#
#                                                    png draw_duration  \
# 0    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        21.803
# 1    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 2    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        22.823
# 3    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        22.873
# 4    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         20.86
# 5    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         0.001
# 6    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        26.053
# 7    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        23.896
# 8    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...          1.65
# 9    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         8.833
# 10   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        23.929
# 11   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        14.151
# 12   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         7.579
# 13   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         5.571
# 14   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         11.46
# 15   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         25.55
# 16   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        19.282
# 17   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 18   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 19   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 20   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         3.617
# 21   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         3.645
# 22   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        11.599
# 23   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         9.616
# 24   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        26.214
# 25   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         6.972
# 26   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        24.353
# 27   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        16.264
# 28   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         4.329
# 29   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        14.195
# ..                                                 ...           ...
# 71   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 72   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 73   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         3.218
# 74   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        22.637
# 75   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        19.945
# 76   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        26.563
# 77   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA
# 86   /Users/langcogresearchassistants/Desktop/kiddr...
# 87   /Users/langcogresearchassistants/Desktop/kiddr...
# 88   /Users/langcogresearchassistants/Desktop/kiddr...
# 89   /Users/langcogresearchassistants/Desktop/kiddr...
# 90   /Users/langcogresearchassistants/Desktop/kiddr...
# 91   /Users/langcogresearchassistants/Desktop/kiddr...
# 92   /Users/langcogresearchassistants/Desktop/kiddr...
# 93   /Users/langcogresearchassistants/Desktop/kiddr...
# 94   /Users/langcogresearchassistants/Desktop/kiddr...
# 95   /Users/langcogresearchassistants/Desktop/kiddr...
# 96   /Users/langcogresearchassistants/Desktop/kiddr...
# 97   /Users/langcogresearchassistants/Desktop/kiddr...
# 98   /Users/langcogresearchassistants/Desktop/kiddr...
# 99   /Users/langcogresearchassistants/Desktop/kiddr...
# 100  /Users/langcogresearchassistants/Desktop/kiddr...
#
# [101 rows x 13 columns]

# %%
categories = [i for i in os.listdir('sketches') if i != '.DS_Store']
num_ims = 0
ims_per_cat = []
for c in categories:
    num_ims += len([i for i in os.listdir(os.path.join('sketches',c)) if i != '.DS_Store'])
    ims_per_cat.append(len([i for i in os.listdir(os.path.join('sketches',c)) if i != '.DS_Store']))
    
print num_ims
print ims_per_cat
# Out:
# 357
# [12, 16, 18, 18, 18, 2, 18, 17, 4, 18, 16, 14, 99, 17, 18, 16, 6, 16, 14]

# %%
plt.bar(categories,ims_per_cat)
frame1=plt.gca()
frame1.axes.get_xaxis().set_visible(False)

# %%
X_out.draw_duration
# Out:
# 0       1.892
# 1       0.951
# 2        1.03
# 3       0.791
# 4       1.002
# 5      12.327
# 6           0
# 7           0
# 8           0
# 9      24.511
# 10       6.05
# 11      5.641
# 12     12.046
# 13      6.698
# 14     10.237
# 15     11.801
# 16     18.474
# 17     19.045
# 18          0
# 19          0
# 20      0.782
# 21      1.268
# 22          0
# 23      0.788
# 24          0
# 25          0
# 26      7.088
# 27          0
# 28          0
# 29          0
#         ...
# 418      None
# 419      None
# 420      None
# 421      None
# 422      None
# 423      None
# 424      None
# 425      None
# 426      None
# 427      None
# 428      None
# 429      None
# 430      None
# 431      None
# 432      None
# 433      None
# 434      None
# 435      None
# 436      None
# 437      None
# 438      None
# 439      None
# 440      None
# 441      None
# 442      None
# 443      None
# 444      None
# 445      None
# 446      None
# 447      None
# Name: draw_duration, Length: 448, dtype: object

# %% [markdown]
# ### load drawing metadata csv back in

# %% [markdown]
# ### Basic visualizations

# %%
fig = plt.figure(figsize=(4,4))
h = plt.hist(X.num_strokes.values,normed=True)
plt.ylabel('proportion')
plt.xlabel('number of strokes')
# Out:
# Text(0.5,0,u'number of strokes')

# %%
fig = plt.figure(figsize=(4,4))
h = plt.hist(X.draw_duration.values,normed=True)
plt.ylabel('proportion')
plt.xlabel('draw duration')
# Out:
# Text(0.5,0,u'draw duration')

# %%
plt.figure(figsize=(20,4))

plt.subplot(1,3,1)
seq = np.arange(4,10)
sns.barplot(data=X,x='category',y='num_strokes',palette="Greens_d")
plt.ylabel('number of strokes')

plt.subplot(1,3,2)
seq = np.arange(4,10)

sns.barplot(data=X,x='category',y='draw_duration', palette="Greens_d")
plt.ylabel('draw duration (s)')

# plt.subplot(1,3,3)
# seq = np.arange(4,10)
# sns.barplot(data=X,x='age',y='mean_intensity',order=seq,palette="Greens_d")
# plt.ylabel('mean pixel intensity')

plt.tight_layout()

# %%
plt.figure(figsize=(20,4))

plt.subplot(1,3,1)
seq = np.arange(4,10)
sns.barplot(data=X,x='condition',y='num_strokes',palette="Greens_d")
plt.ylabel('number of strokes')

plt.subplot(1,3,2)
seq = np.arange(4,10)

sns.barplot(data=X,x='condition',y='draw_duration', palette="Greens_d")
plt.ylabel('draw duration (s)')

# plt.subplot(1,3,3)
# seq = np.arange(4,10)
# sns.barplot(data=X,x='age',y='mean_intensity',order=seq,palette="Greens_d")
# plt.ylabel('mean pixel intensity')

plt.tight_layout()

# %%
plt.figure(figsize=(20,4))

plt.subplot(1,3,1)
seq = np.arange(4,10)
sns.barplot(data=X,x='subID',y='num_strokes',palette="Greens_d")
plt.ylabel('number of strokes')

plt.subplot(1,3,2)
seq = np.arange(4,10)

sns.barplot(data=X,x='subID',y='draw_duration', palette="Greens_d")
plt.ylabel('draw duration (s)')

# plt.subplot(1,3,3)
# seq = np.arange(4,10)
# sns.barplot(data=X,x='age',y='mean_intensity',order=seq,palette="Greens_d")
# plt.ylabel('mean pixel intensity')

plt.tight_layout()

# %%
unique = X.drop_duplicates(["session_id"])
unique.count()
# sum(unique.age != 'adult')
sum(unique.age != 'adult')
# Out:
# 140

# %%
X.

# %%
unique
# Out:
#                       session_id trial_num     category    age  submit_time  \
# 0      cdm_run_test1524766380234         0       square  adult  1.52477e+12
# 1      cdm_run_test1524766518460         0       square   age5  1.52477e+12
# 3    stationPilot1_1524766676245         0       square   age5  1.52477e+12
# 14     cdm_run_test1524767095441         0       square   age8  1.52477e+12
# 15   stationPilot1_1524767406267         0       square   age8  1.52477e+12
# 18   stationPilot1_1524767460609         0       square   age9  1.52477e+12
# 30   stationPilot1_1524767677268         0       square   age9  1.52477e+12
# 32     cdm_run_test1524767999442         0       square   age8  1.52477e+12
# 33   stationPilot1_1524768031714         0       square  age10  1.52477e+12
# 40   stationPilot1_1524768165944         0       square   age9  1.52477e+12
# 41     cdm_run_test1524768273907         0       square  adult  1.52477e+12
# 51   stationPilot1_1524768583158         0       square   age3  1.52477e+12
# 54   stationPilot1_1524768691693         0       square   age3  1.52477e+12
# 58   stationPilot1_1524768885837         2  this circle   age3  1.52477e+12
# 68     cdm_run_test1524769263535         0       square   age5  1.52477e+12
# 80   stationPilot1_1524770599144         0       square  adult  1.52477e+12
# 81     cdm_run_test1524772253302         0       square  adult  1.52477e+12
# 87     cdm_run_test1524772855773         0       square   age2  1.52477e+12
# 99   stationPilot1_1524773265153         0       square   age2  1.52477e+12
# 101  stationPilot1_1524773380150         0       square  adult  1.52477e+12
# 113  stationPilot1_1524773907792         0       square  adult  1.52477e+12
# 124  stationPilot1_1524774211399         0       square   age4  1.52477e+12
# 131    cdm_run_test1524774855213         0       square  adult  1.52477e+12
# 132    cdm_run_test1524775705471         0       square  adult  1.52478e+12
# 133    cdm_run_test1524776059907         0       square   age3  1.52478e+12
# 145  stationPilot1_1524777289150         1        shape   age2  1.52478e+12
# 156    cdm_run_test1524778390077         0       square  adult  1.52478e+12
# 168      cdm_run_v21524779354779         0       square  adult  1.52478e+12
# 169      cdm_run_v21524782553162         0       square  adult  1.52478e+12
# 171      cdm_run_v21524783856057         0       square  adult  1.52478e+12
# ..                           ...       ...          ...    ...          ...
# 500      cdm_run_v21525215311428         0       square   age2  1.52522e+12
# 512      cdm_run_v21525217652340         0       square  adult  1.52522e+12
# 523      cdm_run_v21525218441146         0       square   age2  1.52522e+12
# 524      cdm_run_v21525219775626         0       square   age2  1.52528e+12
# 526      cdm_run_v21525281217296         0       square   age2  1.52528e+12
# 528      cdm_run_v21525281322399         0       square  adult  1.52528e+12
# 539      cdm_run_v21525282894438         0       square  adult  1.52528e+12
# 542      cdm_run_v21525283565462         0       square  adult  1.52528e+12
# 544      cdm_run_v21525283812409         0       square  adult  1.52528e+12
# 556      cdm_run_v21525284909599         0       square  adult  1.52529e+12
# 561      cdm_run_v21525285819658         0       square   age2  1.52529e+12
# 563      cdm_run_v21525286052437         0       square   age8  1.52529e+12
# 564      cdm_run_v21525286901090         0       square   age3  1.52529e+12
# 575      cdm_run_v21525287392928         0       square   age3  1.52529e+12
# 578      cdm_run_v21525288102233         0       square   age3  1.52529e+12
# 581      cdm_run_v21525290944594         0       square   age3  1.52529e+12
# 582      cdm_run_v21525291006459         0       square   age2  1.52529e+12
# 590      cdm_run_v21525292369468         0       square   age4  1.52529e+12
# 596      cdm_run_v21525297716631         0       square  adult   1.5253e+12
# 598      cdm_run_v21525297791022         3        a car   age4   1.5253e+12
# 600      cdm_run_v21525298316576         0       square   age3   1.5253e+12
# 601      cdm_run_v21525298849851         0       square   age3   1.5253e+12
# 608      cdm_run_v21525298979561         0       square   age3   1.5253e+12
# 614      cdm_run_v21525299105215         0       square   age3   1.5253e+12
# 615      cdm_run_v21525301626612         0       square  adult   1.5253e+12
# 627      cdm_run_v21525302271051         0       square   age2   1.5253e+12
# 635      cdm_run_v21525303962336         0       square   age5   1.5253e+12
# 637      cdm_run_v21525304014539         0       square   age5   1.5253e+12
# 642      cdm_run_v21525304115980         0       square   age3   1.5253e+12
# 643      cdm_run_v21525304147638         0       square   age3   1.5253e+12
#
#                   submit_date num_strokes  \
# 0    2018-04-26T18:13:19.827Z           2
# 1    2018-04-26T18:17:34.102Z           1
# 3    2018-04-26T18:19:12.145Z           1
# 14   2018-04-26T18:30:05.270Z         135
# 15   2018-04-26T18:30:30.271Z           2
# 18   2018-04-26T18:31:43.009Z           1
# 30   2018-04-26T18:35:11.560Z           1
# 32   2018-04-26T18:40:30.873Z           1
# 33   2018-04-26T18:41:05.915Z           1
# 40   2018-04-26T18:43:18.263Z           9
# 41   2018-04-26T18:46:47.580Z           1
# 51   2018-04-26T18:50:45.246Z          20
# 54   2018-04-26T18:52:33.077Z          10
# 58   2018-04-26T18:55:22.309Z           1
# 68   2018-04-26T19:03:57.261Z           2
# 80   2018-04-26T19:23:30.933Z           1
# 81   2018-04-26T19:55:36.831Z           1
# 58                                                  []
# 68   [M236,230.96875h1h1h1h1h2h2h1h2h3h2h2h2h3h3l3,...
# 80   [M558,210.96875v3v3v6v7v7v10v8v11v10l1,11l1,13...
# 81   [M264,162.96875h3h2h3h4l3,-1h4h4h4l4,-1h4h4h4h...
# 87   [M223,234.96875h1h2h2h2h3h2h2h4h3h3h3h4h3h4h5h...
# 99   [M391,428.96875l-4,-3l-4,-2l-3,-2l-2,-1l-2,-1l...
# 101  [M241,217.96875h1h1h1h1v1h2l1,1h1h1h2l1,1h2h1h...
# 113  [M256,243.96875v2v3v3v5v4v6v6v7v7v6l-1,8l-1,8l...
# 124  [M303,499.96875v-1v-2v-2v-2v-2v-2l-1,-2v-2v-1l...
# 131  [M234,233.96875v5l-1,7v8v10v11v14v14v15v18v18v...
# 132  [M154,312.96875v3l2,8l3,6, M287,159.96875l8,-4...
# 133  [M546,246.96875l-5,-1h-1h-2h-2h-2h-2h-2h-3h-3h...
# 145  [M252,542.96875l-6,-5v-1v-1v-1v-1v-2l1,-1v-1v-...
# 156  [M559,219.96875l-1,14v2v2v3v4v3v4v4v4v5v5v5l1,...
# 168  [M230,202.96875l-7,6v2v2l1,2l2,2l1,2l2,2l2,1l3...
# 169  [M226,225.96875h5h3h4h6h6h8h8h11l10,-1l11,-1l1...
# 171  [M462.19299,2579.58838v63.92285v31.01318v11.01...
# ..                                                 ...
# 500  [M227,508.96875l-8,-9v-2l-3,-4l-2,-3l-2,-4l-2,...
# 512  [M253,230.96875l-1,13v3v2v3v4v3v3v4v4v3v5v4v4v...
# 523  [M94,675.96875l4,10v2l1,1l1,2l1,2l3,2l3,4l4,5l...
# 524  [M471,374.96875l-10,4h-1h-2l-2,1l-2,1l-3,1l-3,...
# 526  [M545,222.96875l2,2v1v1v1v1v2h-1v1v2h-1v1v1v1v...
# 528  [M241,228.96875l1,1h1h1h1h1l1,1h1h1h1h1h1h1l1,...
# 539  [M240,248.96875l-3,7v4v6l-1,7l-1,8v10v9v13v11v...
# 542  [M73,553.96875l1,-6l1,-9l3,-11l3,-11l4,-11l4,-...
# 544  [M243,233.96875l-5,2v1v3v2v3v2v2v3v3v2v2v2v2v3...
# 556  [M233,561.96875, M236,557.96875l-2,-4v-1v-1v-1...
# 561  [M250,235.96875l-3,4v3l-1,4v3l-1,4v5l-1,3l-2,5...
# 563  [M138,203.96875, M138,203.96875l323,-103, M352...
# 564  [M104,474.96875v-3v-4v-6v-5l1,-4l1,-5l1,-6l3,-...
# 575  [M415,352.96875v10v6l1,7l1,6l1,8l1,7l1,6l1,7l1...
# 578  [M177,202.96875l-3,-13l-1,-8v-5v-6v-6v-6v-6l2,...
# 581  [M242,505.96875v-7v-4v-3v-3l1,-3l1,-3l1,-3v-1v...
# 582  [M327,379.96875l3,-9l3,-2h2l2,-1h1h1l1,1v1v2v2...
# 590  [M223,214.96875l4,6v2l1,2l1,2l1,2l1,3v3l1,2l1,...
# 596  [M277,251.96875l2,5h2h2h2h2h2h2h3h2l2,1h2h2l2,...
# 598  [M244,337.96875l20,-9l13,-4l40,-13l15,-5l18,-4...
# 600  [M251,201.96875l-4,18l1,1v1l1,1v1l1,1l1,1v1v1v...
# 601  [M520,546.96875l6,-4l2,-1l3,-1l2,-2l1,-2l2,-2l...
# 608  [M75,670.96875l2,4h2l2,1l4,1l4,2h5l7,2l5,1l8,2...
# 614  [M411,567.96875l10,-9l5,-6v0l3,-1l-14,39l-3,6l...
# 615  [M223,228.96875l3,13v3v2v3v2v3v3v3v3l-2,3l-1,3...
# 627  [M362,375.96875l-6,-2l-1,3l-5,6l-5,8l-5,8l-6,1...
# 635  [M219,248.96875l5,-5l1,-1l1,-1l1,-1l1,-1l2,-1l...
# 637  [M213,219.96875l9,4h1h2h2h1h2h2h1h1h1h2h1h2h2h...
# 642  [M222,233.96875l9,11v2l1,1l1,1v3v2v3v3v4v4l-1,...
# 643  [M215,346.96875l2,1v3v4v4v5v5v4v5v4v4v4v3v4v4v...
#
#                                              svg_times  \
# 0               [1.52476639554e+12, 1.52476639588e+12]
# 1                                  [1.52476665118e+12]
# 3                                  [1.52476674489e+12]
# 14   [1.5247673804e+12, 1.52476738661e+12, 1.524767...
# 15              [1.52476741993e+12, 1.52476742888e+12]
# 18                                 [1.52476750028e+12]
# 30                                 [1.52476771043e+12]
# 32                                 [1.52476802937e+12]
# 33                                 [1.52476806297e+12]
# 40   [1.52476818331e+12, 1.52476818799e+12, 1.52476...
# 41                                 [1.52476840638e+12]
# 51   [1.52476862933e+12, 1.52476863389e+12, 1.52476...
# 54   [1.52476874314e+12, 1.52476874315e+12, 1.52476...
# 58                                  [1.5247689107e+12]
# 68              [1.52476942838e+12, 1.52476943318e+12]
# 80                                 [1.52477060988e+12]
# 81                                 [1.52477252981e+12]
# 87              [1.52477296608e+12, 1.52477297592e+12]
# 99                                 [1.52477328998e+12]
# 101                                [1.52477369567e+12]
# 113                                [1.52477399947e+12]
# 124                                [1.52477427668e+12]
# 131                                [1.52477488162e+12]
# 132  [1.5247757157e+12, 1.52477571623e+12, 1.524775...
# 133  [1.524776864e+12, 1.524776864e+12, 1.524776865...
# 145  [1.52477740543e+12, 1.52477740543e+12, 1.52477...
# 156                                [1.52477841591e+12]
# 168                                [1.52477936534e+12]
# 169                                [1.52478262336e+12]
# 171                                [1.52478387793e+12]
# ..                                                 ...
# 500                                [1.52521533305e+12]
# 512                                [1.52521813752e+12]
# 523  [1.52521850748e+12, 1.52521850916e+12, 1.52521...
# 524  [1.52528110453e+12, 1.52528110714e+12, 1.52528...
# 526  [1.52528124144e+12, 1.52528124455e+12, 1.52528...
# 528                                  [1.525282657e+12]
# 539                                [1.52528299472e+12]
# 542  [1.52528358984e+12, 1.52528359013e+12, 1.52528...
# 544                                [1.52528392629e+12]
# 556             [1.52528562686e+12, 1.52528563533e+12]
# 561                                [1.52528600598e+12]
# 563  [1.52528688629e+12, 1.5252868863e+12, 1.525286...
# 564                                [1.52528692279e+12]
# 575  [1.52528742629e+12, 1.52528742629e+12, 1.52528...
# 578  [1.52529086752e+12, 1.52529087041e+12, 1.52529...
# 581                                [1.52529097426e+12]
# 582  [1.52529219305e+12, 1.52529219895e+12, 1.52529...
# 590             [1.52529272868e+12, 1.52529273683e+12]
# 596                                [1.52529773985e+12]
# 598             [1.52529827017e+12, 1.52529827086e+12]
# 600  [1.52529884496e+12, 1.52529884496e+12, 1.52529...
# 601  [1.52529887417e+12, 1.52529887417e+12, 1.52529...
# 608              [1.5252990184e+12, 1.52529901842e+12]
# 614  [1.52529910543e+12, 1.52529910543e+12, 1.52529...
# 615                                [1.52530205916e+12]
# 627  [1.52530347564e+12, 1.52530347751e+12, 1.52530...
# 635                                [1.52530399105e+12]
# 637                                 [1.5253040435e+12]
# 642  [1.52530414108e+12, 1.52530414108e+12, 1.52530...
# 643  [1.52530417678e+12, 1.52530417678e+12, 1.52530...
#
#                                                    png draw_duration  \
# 0    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         0.337
# 1    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 3    iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 14   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        22.229
# 15   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         8.952
# 18   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 30   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 32   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 33   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 40   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        11.481
# 41   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 51   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        13.906
# 54   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         8.461
# 58   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 68   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         4.799
# 80   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 81   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 87   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         9.839
# 99   iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 101  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 113  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 124  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 131  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 132  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        20.509
# 133  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        10.619
# 145  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        23.483
# 156  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 168  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 169  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 171  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# ..                                                 ...           ...
# 500  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 512  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 523  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        12.382
# 524  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        10.089
# 526  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        19.726
# 528  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 539  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 542  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         0.755
# 544  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 556  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...          8.47
# 561  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 563  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        11.225
# 564  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 575  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        11.864
# 578  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...          8.21
# 581  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 582  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         11.51
# 590  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         8.154
# 596  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 598  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         0.687
# 600  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         2.374
# 601  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         2.498
# 608  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         0.016
# 614  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         0.001
# 615  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 627  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...        12.014
# 635  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 637  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...             0
# 642  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         0.927
# 643  iVBORw0KGgoAAAANSUhEUgAAAJYAAACWCAYAAAA8AXHiAA...         17.79
#
#                                               filename
# 0    /Users/brialong/Documents/GitHub/kiddraw/analy...
# 1    /Users/brialong/Documents/GitHub/kiddraw/analy...
# 3    /Users/brialong/Documents/GitHub/kiddraw/analy...
# 14   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 15   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 18   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 30   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 32   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 33   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 40   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 41   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 51   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 54   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 58   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 68   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 80   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 81   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 87   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 99   /Users/brialong/Documents/GitHub/kiddraw/analy...
# 101  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 113  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 124  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 131  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 132  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 133  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 145  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 156  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 168  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 169  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 171  /Users/brialong/Documents/GitHub/kiddraw/analy...
# ..                                                 ...
# 500  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 512  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 523  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 524  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 526  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 528  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 539  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 542  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 544  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 556  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 561  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 563  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 564  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 575  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 578  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 581  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 582  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 590  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 596  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 598  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 600  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 601  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 608  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 614  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 615  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 627  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 635  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 637  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 642  /Users/brialong/Documents/GitHub/kiddraw/analy...
# 643  /Users/brialong/Documents/GitHub/kiddraw/analy...
#
# [117 rows x 12 columns]

# %%
categories = [i for i in os.listdir('sketches') if i != '.DS_Store']
num_ims = 0
ims_per_cat = []
for c in categories:
    num_ims += len([i for i in os.listdir(os.path.join('sketches',c)) if i != '.DS_Store'])
    ims_per_cat.append(len([i for i in os.listdir(os.path.join('sketches',c)) if i != '.DS_Store']))
    
print num_ims
print ims_per_cat
# Out:
# 1106
# [78, 78, 82, 78, 82, 79, 80, 76, 135, 48, 172, 118]
